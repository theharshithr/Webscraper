# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshithr3/Webscraper/blob/master/py_project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup 
import requests

url='https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DRealme&otracker=clp_metro_expandable_1_5.metroExpandable.METRO_EXPANDABLE_mobile-phones-store_25DMXHG2C5AT_wp3&fm=neo%2Fmerchandising&iid=M_98e5083b-8059-45fe-9a20-3fd87ce4bbfc_5.25DMXHG2C5AT&ssid=xrbgd7ag5c0000001597749099563'
page=requests.get(url)

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.21be2e.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %%
soup = BeautifulSoup(page.text, 'html.parser')
soup.title
# Out:
# <title>Mobile Price List | Compare Mobiles and Buy Online @ Flipkart</title>

# %%
name = []
price = []
rating = []
for a in soup.findAll('a',href=True,attrs={'class':'_31qSD5'}):
  model=a.find('div',attrs={'class':'_3wU53n'})
  cost=a.find('div',attrs={'class':'_1vC4OE _2rQ-NK'})
  rating1=a.find('div',attrs={'class':'hGSR34'})
  name.append(model.text)
  price.append(cost.text)
  rating.append(rating1.text)

# %%
name
# Out:
# ['Realme C2 (Diamond Blue, 32 GB)',
#  'Realme C3 (Frozen Blue, 32 GB)',
#  'Realme 6 (Comet Blue, 64 GB)',
#  'Realme 6i (Eclipse Black, 64 GB)',
#  'Realme 6i (Lunar White, 64 GB)',
#  'Realme 6i (Lunar White, 64 GB)',
#  'Realme 6i (Eclipse Black, 64 GB)',
#  'Realme 6 Pro (Lightning Blue, 128 GB)',
#  'Realme C11 (Rich Grey, 32 GB)',
#  'Realme C11 (Rich Green, 32 GB)',
#  'Realme 6 (Comet White, 64 GB)',
#  'Realme 6 (Comet Blue, 128 GB)',
#  'Realme Narzo 10 (That Green, 128 GB)',
#  'Realme Narzo 10 (That White, 128 GB)',
#  'Realme Narzo 10 (That Blue, 128 GB)',
#  'Realme 6 Pro (Lightning Blue, 64 GB)',
#  'Realme Narzo 10A (So White, 32 GB)',
#  'Realme Narzo 10A (So Blue, 32 GB)',
#  'Realme Narzo 10A (So Blue, 64 GB)',
#  'Realme Narzo 10A (So White, 64 GB)',
#  'Realme 6 (Comet White, 128 GB)',
#  'Realme X2 (Pearl Blue, 256 GB)',
#  'Realme 5 Pro (Sparkling Blue, 128 GB)',
#  'Realme 5 Pro (Sparkling Blue, 64 GB)']

# %%
price
# Out:
# ['₹6,999',
#  '₹8,999',
#  '₹15,999',
#  '₹14,999',
#  '₹12,999',
#  '₹14,999',
#  '₹12,999',
#  '₹19,999',
#  '₹7,499',
#  '₹7,499',
#  '₹15,999',
#  '₹17,999',
#  '₹11,999',
#  '₹11,999',
#  '₹11,999',
#  '₹17,999',
#  '₹8,999',
#  '₹8,999',
#  '₹9,999',
#  '₹9,999',
#  '₹17,999',
#  '₹22,999',
#  '₹16,999',
#  '₹14,999']

# %%
import pandas as pd
df=pd.DataFrame(list(zip(name,price,rating)))
df.columns=['Name','Price','Rating']

# %%
df
# Out:
#                                      Name    Price Rating
# 0         Realme C2 (Diamond Blue, 32 GB)   ₹6,999    4.4
# 1          Realme C3 (Frozen Blue, 32 GB)   ₹8,999    4.5
# 2            Realme 6 (Comet Blue, 64 GB)  ₹15,999    4.4
# 3        Realme 6i (Eclipse Black, 64 GB)  ₹14,999    4.5
# 4          Realme 6i (Lunar White, 64 GB)  ₹12,999    4.5
# 5          Realme 6i (Lunar White, 64 GB)  ₹14,999    4.5
# 6        Realme 6i (Eclipse Black, 64 GB)  ₹12,999    4.5
# 7   Realme 6 Pro (Lightning Blue, 128 GB)  ₹19,999    4.4
# 8           Realme C11 (Rich Grey, 32 GB)   ₹7,499    4.4
# 9          Realme C11 (Rich Green, 32 GB)   ₹7,499    4.4
# 10          Realme 6 (Comet White, 64 GB)  ₹15,999    4.4
# 11          Realme 6 (Comet Blue, 128 GB)  ₹17,999    4.4
# 12   Realme Narzo 10 (That Green, 128 GB)  ₹11,999    4.5
# 13   Realme Narzo 10 (That White, 128 GB)  ₹11,999    4.5
# 14    Realme Narzo 10 (That Blue, 128 GB)  ₹11,999    4.5
# ...
